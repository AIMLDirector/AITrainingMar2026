# %% [markdown]
# pandas -- Two objects(Series / data frames)
# Series - Sequence of data values -- List  - [1,2,3,4,5]
# dataframe - row and column information ( csv, excel, db tables)  - Data frame are tables

# %%
pip list
# Out:
# Package                   Version
# ------------------------- -----------
# anyio                     4.12.1
# appnope                   0.1.4
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.2.0
# attrs                     25.4.0
# babel                     2.18.0
# beautifulsoup4            4.14.3
# bleach                    6.3.0
# certifi                   2026.2.25
# cffi                      2.0.0
# charset-normalizer        3.4.5
# comm                      0.2.3
# contourpy                 1.3.3
# cycler                    0.12.1
# debugpy                   1.8.20
# decorator                 5.2.1
# defusedxml                0.7.1
# executing                 2.2.1
# fastjsonschema            2.21.2
# fonttools                 4.62.1
# fqdn                      1.5.1
# h11                       0.16.0
# httpcore                  1.0.9
# ...

# %%
import pandas as pd

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([1,2,3,4,5], index= ['A','B','C','D','E'], name ="number Series")
# Out:
# A    1
# B    2
# C    3
# D    4
# E    5
# Name: number Series, dtype: int64

# %%
df = pd.DataFrame({"Name": ["sam", "john"], "id": [101,102]})

# %%
df
# Out:
#    Name   id
# 0   sam  101
# 1  john  102

# %%
df['Name']
# Out:
# 0     sam
# 1    john
# Name: Name, dtype: str

# %%
df.Name
# Out:
# 0     sam
# 1    john
# Name: Name, dtype: str

# %%
df[['Name', 'id']]
# Out:
#    Name   id
# 0   sam  101
# 1  john  102

# %%
df
# Out:
#    Name   id
# 0   sam  101
# 1  john  102

# %%
df.loc[0:1]
# Out:
#    Name   id
# 0   sam  101
# 1  john  102

# %%
df.shape
# Out:
# (2, 2)

# %%
df.describe()
# Out:
#                id
# count    2.000000
# mean   101.500000
# std      0.707107
# min    101.000000
# 25%    101.250000
# 50%    101.500000
# 75%    101.750000
# max    102.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      str
#  1   id      2 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 164.0 bytes

# %%
df = pd.read_csv("employees.csv")

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    str
#  1   Gender             855 non-null    str
#  2   Start Date         1000 non-null   str
#  3   Last Login Time    1000 non-null   str
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    str
# dtypes: float64(1), int64(1), object(1), str(5)
# memory usage: 62.6+ KB

# %%
df[['Gender', 'Senior Management', 'Team']]
# Out:
#      Gender Senior Management                  Team
# 0      Male              True             Marketing
# 1      Male              True                   NaN
# 2    Female             False               Finance
# 3      Male              True               Finance
# 4      Male              True       Client Services
# ..      ...               ...                   ...
# 995     NaN             False          Distribution
# 996    Male             False               Finance
# 997    Male             False               Product
# 998    Male             False  Business Development
# 999    Male              True                 Sales
#
# [1000 rows x 3 columns]

# %%
df_filter = df[(df['Team'] == 'Finance') & (df['Gender'] == 'Male')]
df_filter
# Out:
#       First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 3          Jerry   Male    3/4/2005         1:00 PM  138705    9.340
# 46         Bruce   Male  11/28/2009        10:47 PM  114796    6.796
# 56          Carl   Male    5/3/2006         5:55 PM  130276   16.084
# 68          Jose   Male  10/30/2004         1:39 PM   84834   14.330
# 83         Shawn   Male   9/23/2005         2:55 AM  148115    6.539
# 117       Steven   Male    3/1/1995         3:03 PM  109095    9.494
# 200         Gary   Male   8/12/1987        12:04 AM   89661    8.525
# 205      Brandon   Male   3/27/2006         5:54 PM  115711    8.012
# 219        Billy   Male   3/13/1995        12:05 PM  120444    7.768
# 222        Jason   Male  10/17/1999        10:09 PM   78417    3.067
# 241       Walter   Male    7/6/1983        11:54 PM  127813    5.961
# 286         Todd   Male    2/2/1984        10:13 AM   69989   10.985
# 304       Jeremy   Male   8/12/1981        12:05 AM   46930   18.702
# ...

# %%
df_filter1 = df_filter.dropna()

# %%
df_filter1.to_csv("Employees_cleaneddata.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    str
#  1   Gender             855 non-null    str
#  2   Start Date         1000 non-null   str
#  3   Last Login Time    1000 non-null   str
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    str
# dtypes: float64(1), int64(1), object(1), str(5)
# memory usage: 62.6+ KB

# %%
df_filetered2 = df.isnull()
df_filetered2
# Out:
#      First Name  Gender  Start Date  Last Login Time  Salary  Bonus %  \
# 0         False   False       False            False   False    False
# 1         False   False       False            False   False    False
# 2         False   False       False            False   False    False
# 3         False   False       False            False   False    False
# 4         False   False       False            False   False    False
# ..          ...     ...         ...              ...     ...      ...
# 995       False    True       False            False   False    False
# 996       False   False       False            False   False    False
# 997       False   False       False            False   False    False
# 998       False   False       False            False   False    False
# 999       False   False       False            False   False    False
#
#      Senior Management   Team
# 0                False  False
# 1                False   True
# 2                False  False
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    str
#  1   Gender             855 non-null    str
#  2   Start Date         1000 non-null   str
#  3   Last Login Time    1000 non-null   str
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    str
# dtypes: float64(1), int64(1), object(1), str(5)
# memory usage: 62.6+ KB

# %%
dfnew= df[df['Team'].notnull() & df['Gender'].notnull()]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(10,4))
plt.plot([1,2,3],[4,5,6])
plt.title(" Testing the plot diagrams")
plt.xlabel("x axis data")
plt.ylabel("y axis data")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# matplotlib, seaborn , plotty
